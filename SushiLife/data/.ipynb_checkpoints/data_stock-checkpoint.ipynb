# %%
import numpy as np
import dask.array as da
import pandas as pd

from loader import *

# %%
filename = "../../data/기관외국인동향.db"
data = read_db_multi(filename, num_process=6)

# %%
data["A005930"]
# Out:
#                   종가       대비      거래량(주)   기관_매수량(주)  기관_매도량(주)  기관_순매수(주)  \
# 날짜
# 2002-01-02  308000.0  29000.0   1142079.0    318980.0   221221.0    97759.0
# 2002-01-03  302000.0  -6000.0    885636.0    303330.0   227320.0    76010.0
# 2002-01-04  319000.0  17000.0   1009482.0    282590.0   302472.0   -19882.0
# 2002-01-07  318000.0  -1000.0   1029132.0    253161.0   332482.0   -79321.0
# 2002-01-08  311500.0  -6500.0    760142.0    169190.0   197621.0   -28431.0
# 2002-01-09  322500.0  11000.0    902401.0    173951.0   305820.0  -131869.0
# 2002-01-10  308000.0 -14500.0   1096986.0    280792.0   471535.0  -190743.0
# 2002-01-11  306000.0  -2000.0    953687.0    224770.0   270770.0   -46000.0
# 2002-01-14  330000.0  24000.0    978026.0    231590.0   201660.0    29930.0
# 2002-01-15  312000.0 -18000.0   1377508.0    331880.0   289150.0    42730.0
# 2002-01-16  301500.0 -10500.0   1206614.0    335530.0   225170.0   110360.0
# ...
